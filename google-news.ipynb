# %%
import gensim.downloader as api

model = api.load("word2vec-google-news-300")

# %%
print(model.most_similar(
    positive=["king", "woman"],
    negative=["man"]
))
# Out:
# [('queen', 0.7118192911148071), ('monarch', 0.6189674735069275), ('princess', 0.5902431011199951), ('crown_prince', 0.5499460697174072), ('prince', 0.5377321243286133), ('kings', 0.5236844420433044), ('Queen_Consort', 0.5235945582389832), ('queens', 0.5181134343147278), ('sultan', 0.5098593235015869), ('monarchy', 0.5087411999702454)]

# %%
print(model.most_similar(
    positive=["euro", "usa"],
    negative=["eu"]
))
# Out:
# [('dollar', 0.5017853379249573), ('Hungarian_forint', 0.4827941656112671), ('Swiss_franc', 0.47861456871032715), ('forint', 0.4717487692832947), ('Romanian_leu', 0.4700077772140503), ('Polish_zloty', 0.4692719280719757), ('yen', 0.46034523844718933), ('Philippine_Peso', 0.4586375951766968), ('Mauritian_rupee', 0.45587489008903503), ('Slovakian_koruna', 0.4525723159313202)]
